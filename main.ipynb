# %%
# %pip install sqlalchemy
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# Requirement already satisfied: sqlalchemy in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from sqlalchemy) (4.11.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (3.9.0)
# Requirement already satisfied: pillow>=8 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: cycler>=0.10 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pillow>=8 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: tzdata>=2022.7 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/holygeek/.pyenv/versions/3.10.9/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '2.0.30'

# %% [markdown]
# ```conda install sqlalchemy```
# ##### The Version of sqlalchemy is 2.0.25

# %%
from sqlalchemy import create_engine, Column, Integer, String, DateTime,Float
from sqlalchemy.orm import sessionmaker,relationship

from sqlalchemy.orm import declarative_base
Base = declarative_base()

# %%
class Train(Base):
    __tablename__='train_datas'

    x=Column(Float,nullable=False,primary_key=True)
    y1=Column(Float,nullable=False)
    y2=Column(Float,nullable=False)
    y3=Column(Float,nullable=False)
    y4=Column(Float,nullable=False)
# Define Training data mode

# %%
class Test(Base):
    __tablename__='test_datas'


    x=Column(Float,nullable=False,primary_key=True)
    y=Column(Float,nullable=False)
    delta_x=Column(Float,nullable=True)
    func_num=Column(Float,nullable=True)

# %%
# Define the IdealFunctions table
class IdealFunctions(Base):
    __tablename__ = 'ideal_functions'
    x=Column(Float,nullable=False,primary_key=True)
    y1 = Column(Float)
    y2 = Column(Float)
    y3 = Column(Float)
    y4 = Column(Float)
    y5 = Column(Float)
    y6 = Column(Float)
    y7 = Column(Float)
    y8 = Column(Float)
    y9 = Column(Float)
    y10 = Column(Float)
    y11 = Column(Float)
    y12 = Column(Float)
    y13 = Column(Float)
    y14 = Column(Float)
    y15 = Column(Float)
    y16 = Column(Float)
    y17 = Column(Float)
    y18 = Column(Float)
    y19 = Column(Float)
    y20 = Column(Float)
    y21 = Column(Float)
    y22 = Column(Float)
    y23 = Column(Float)
    y24 = Column(Float)
    y25 = Column(Float)
    y26 = Column(Float)
    y27 = Column(Float)
    y28 = Column(Float)
    y29 = Column(Float)
    y30 = Column(Float)
    y31 = Column(Float)
    y32 = Column(Float)
    y33 = Column(Float)
    y34 = Column(Float)
    y35 = Column(Float)
    y36 = Column(Float)
    y37 = Column(Float)
    y38 = Column(Float)
    y39 = Column(Float)
    y40 = Column(Float)
    y41 = Column(Float)
    y42 = Column(Float)
    y43 = Column(Float)
    y44 = Column(Float)
    y45 = Column(Float)
    y46 = Column(Float)
    y47 = Column(Float)
    y48 = Column(Float)
    y49 = Column(Float)
    y50 = Column(Float)

# %%
# Create an engine to connect to an SQLite database (or create it if it doesn't exist)
engine = create_engine('sqlite:///assignment_data.db')

# Create all tables in the database defined by Base's subclasses
Base.metadata.create_all(engine)

# %%
import pandas as pd

# load the data into a Pandas DataFrame
train = pd.read_csv('train.csv')

train.to_sql('train_datas', con=engine, if_exists='replace', index=False)
# Out:
# 400

# %%
# Read data from the table
df = pd.read_sql('SELECT * FROM train_datas', con=engine)

# Display the first few rows of the DataFrame
print(df)
# Out:
#         x         y1         y2         y3        y4
# 0   -20.0  39.778572 -40.078590 -20.214268 -0.324914
# 1   -19.9  39.604813 -39.784000 -20.070950 -0.058820
# 2   -19.8  40.099070 -40.018845 -19.906782 -0.451830
# 3   -19.7  40.151100 -39.518402 -19.389118 -0.612044
# 4   -19.6  39.795662 -39.360065 -19.815890 -0.306076
# ..    ...        ...        ...        ...       ...
# 395  19.5 -38.254158  39.661987  19.536741  0.695158
# 396  19.6 -39.106945  39.067880  19.840752  0.638423
# 397  19.7 -38.926495  40.211475  19.516634  0.109105
# 398  19.8 -39.276672  40.038870  19.377943  0.189025
# 399  19.9 -39.724934  40.558865  19.630678  0.513824
#
# [400 rows x 5 columns]

# %%
# load the data into a Pandas DataFrame
test = pd.read_csv('test.csv')

test.to_sql('test_datas', con=engine, if_exists='replace', index=False)
# Out:
# 100

# %%
# Read data from the table
df = pd.read_sql('SELECT * FROM test_datas', con=engine)

# Display the first few rows of the DataFrame
print(df)
# Out:
#        x          y
# 0   17.5  34.161040
# 1    0.3   1.215102
# 2   -8.7 -16.843908
# 3  -19.2 -37.170870
# 4  -11.0 -20.263054
# ..   ...        ...
# 95  -1.9  -4.036904
# 96  12.2  -0.010358
# 97  16.5 -33.964134
# 98   5.3 -10.291622
# 99  17.9  28.078455
#
# [100 rows x 2 columns]

# %%
ideal = pd.read_csv('ideal.csv')

ideal.to_sql('ideal_functions', con=engine, if_exists='replace', index=False)
# Out:
# 400

# %%
# Read data from the table
df = pd.read_sql('SELECT * FROM ideal_functions', con=engine)

# Display the first few rows of the DataFrame
print(df)
# Out:
#         x        y1        y2         y3        y4         y5        y6  \
# 0   -20.0 -0.912945  0.408082   9.087055  5.408082  -9.087055  0.912945
# 1   -19.9 -0.867644  0.497186   9.132356  5.497186  -9.132356  0.867644
# 2   -19.8 -0.813674  0.581322   9.186326  5.581322  -9.186326  0.813674
# 3   -19.7 -0.751573  0.659649   9.248426  5.659649  -9.248426  0.751573
# 4   -19.6 -0.681964  0.731386   9.318036  5.731386  -9.318036  0.681964
# ..    ...       ...       ...        ...       ...        ...       ...
# 395  19.5  0.605540  0.795815  10.605540  5.795815 -10.605540 -0.605540
# 396  19.6  0.681964  0.731386  10.681964  5.731386 -10.681964 -0.681964
# 397  19.7  0.751573  0.659649  10.751574  5.659649 -10.751574 -0.751573
# 398  19.8  0.813674  0.581322  10.813674  5.581322 -10.813674 -0.813674
# 399  19.9  0.867644  0.497186  10.867644  5.497186 -10.867644 -0.867644
#
#            y7        y8        y9  ...        y41        y42       y43  \
# 0   -0.839071 -0.850919  0.816164  ... -40.456474  40.204040  2.995732
# 1   -0.865213  0.168518  0.994372  ... -40.233820  40.048590  2.990720
# 2   -0.889191  0.612391  1.162644  ... -40.006836  39.890660  2.985682
# 3   -0.910947 -0.994669  1.319299  ... -39.775787  39.729824  2.980619
# 4   -0.930426  0.774356  1.462772  ... -39.540980  39.565693  2.975530
# ..        ...       ...       ...  ...        ...        ...       ...
# 395 -0.947580 -0.117020  1.591630  ...  39.302770 -38.602093  2.970414
# 396 -0.930426  0.774356  1.462772  ...  39.540980 -38.834310  2.975530
# 397 -0.910947 -0.994669  1.319299  ...  39.775787 -39.070175  2.980619
# 398 -0.889191  0.612391  1.162644  ...  40.006836 -39.309338  2.985682
# 399 -0.865213  0.168518  0.994372  ...  40.233820 -39.551407  2.990720
#
#           y44        y45       y46       y47       y48       y49       y50
# 0   -0.008333  12.995732  5.298317 -5.298317 -0.186278  0.912945  0.396850
# 1   -0.008340  12.990720  5.293305 -5.293305 -0.215690  0.867644  0.476954
# 2   -0.008347  12.985682  5.288267 -5.288267 -0.236503  0.813674  0.549129
# 3   -0.008354  12.980619  5.283204 -5.283204 -0.247887  0.751573  0.612840
# 4   -0.008361  12.975530  5.278115 -5.278115 -0.249389  0.681964  0.667902
# ..        ...        ...       ...       ...       ...       ...       ...
# 395 -0.012422  12.970414  5.273000 -5.273000  0.240949  0.605540  0.714434
# 396 -0.012438  12.975530  5.278115 -5.278115  0.249389  0.681964  0.667902
# 397 -0.012453  12.980619  5.283204 -5.283204  0.247887  0.751573  0.612840
# 398 -0.012469  12.985682  5.288267 -5.288267  0.236503  0.813674  0.549129
# 399 -0.012484  12.990720  5.293305 -5.293305  0.215690  0.867644  0.476954
#
# [400 rows x 51 columns]

# %%
def load_data_to_dataframe(table_name, engine):
    return pd.read_sql_table(table_name, con=engine)

# Load data from each table
train_data = load_data_to_dataframe('train_datas', engine)
ideal_functions = load_data_to_dataframe('ideal_functions', engine)
test_data = load_data_to_dataframe('test_datas', engine)

# %%
import pandas as pd
import numpy as np

# Assuming data is loaded into DataFrame train_data, test_data, and ideal_functions
# Let's create a function to find the ideal functions

import pandas as pd
import numpy as np

def calculate_least_squares(y_train, y_ideal):
    return np.sum((y_train - y_ideal) ** 2)

def find_best_ideal_functions(training_data, ideal_functions, n=4):
    if not isinstance(training_data, pd.DataFrame) or not isinstance(ideal_functions, pd.DataFrame):
        raise ValueError("Both training_data and ideal_functions must be pandas DataFrames.")
    if not isinstance(n, int):
        raise ValueError("n must be an integer.")

    best_funcs = {}
    
    for i in range(1, n + 1):
        min_deviation = float('inf')
        best_func = None
        
        for ideal in ideal_functions.columns[1:]:
            deviation = calculate_least_squares(training_data[f'y{i}'], ideal_functions[ideal])
            
            if deviation < min_deviation:
                min_deviation = deviation
                best_func = ideal
        
        best_funcs[f'IdealFunc{i}'] = best_func
    
    return best_funcs


# Example usage:
# training_data and ideal_functions are DataFrames with loaded CSV data
best_funcs = find_best_ideal_functions(train_data, ideal_functions)
print(best_funcs)
# Out:
# {'IdealFunc1': 'y42', 'IdealFunc2': 'y41', 'IdealFunc3': 'y11', 'IdealFunc4': 'y48'}

# %%
import numpy as np
import pandas as pd

def map_test_data(test_data, ideal_functions, best_funcs):
    if not isinstance(test_data, pd.DataFrame) or not isinstance(ideal_functions, pd.DataFrame):
        raise ValueError("test_data and ideal_functions must be pandas DataFrame objects")
    
    if not 'x' in test_data or not 'y' in test_data:
        raise ValueError("test_data must contain 'x' and 'y' columns")
    
    if not 'x' in ideal_functions:
        raise ValueError("ideal_functions must contain an 'x' column")
    
    # Preprocessing to optimize queries
    ideal_functions = ideal_functions.set_index('x')
    
    results = []
    max_deviation_threshold = float('inf')  # Define a threshold if necessary

    for index, row in test_data.iterrows():
        x = row['x']
        y_test = row['y']
        closest_func = "none"  # Default if no function matches well
        min_deviation = float('inf')
        
        # Compare against each of the best matching ideal functions
        for train_col, ideal_col in best_funcs.items():
            if x in ideal_functions.index:
                y_ideal = ideal_functions.at[x, ideal_col] if pd.notna(ideal_functions.at[x, ideal_col]) else np.nan
                if pd.notna(y_ideal):
                    deviation = (y_test - y_ideal) ** 2
                    if deviation < min_deviation:
                        min_deviation = deviation
                        closest_func = ideal_col
        
        # Set a high default value if no match found within the threshold
        delta_x = np.sqrt(min_deviation) if min_deviation != float('inf') and min_deviation <= max_deviation_threshold else np.nan
        
        results.append({'x': x, 'y': y_test, 'delta_x': delta_x, 'func_num': closest_func})

    return pd.DataFrame(results)

# Example usage
try:
    mapped_test_data = map_test_data(test_data, ideal_functions, best_funcs)
    mapped_test_data.to_sql('test_datas', con=engine, if_exists='replace', index=False)
    # Retrieve and display data to confirm
    test_data = pd.read_sql('SELECT * FROM test_datas', con=engine)
    print(test_data)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#        x          y   delta_x func_num
# 0   17.5  34.161040  0.351148      y41
# 1    0.3   1.215102  0.467342      y41
# 2   -8.7 -16.843908  0.887577      y41
# 3  -19.2 -37.170870  1.400790      y41
# 4  -11.0 -20.263054  1.236952      y41
# ..   ...        ...       ...      ...
# 95  -1.9  -4.036904  0.236246      y41
# 96  12.2  -0.010358  0.156869      y48
# 97  16.5 -33.964134  0.612934      y42
# 98   5.3 -10.291622  0.031191      y42
# 99  17.9  28.078455  7.314965      y41
#
# [100 rows x 4 columns]

# %%
# Import necessary libraries for visualization

import matplotlib.pyplot as plt
import seaborn as sns

# Import necessary libraries for SQLAlchemy
from sqlalchemy import create_engine, Column, Integer, String, DateTime, Float
from sqlalchemy.orm import sessionmaker, relationship, declarative_base

# Define SQLAlchemy base
Base = declarative_base()


# Define a function to plot data from the Train table
def plot_train_data(session):
    train_data = session.query(Train).all()
    x = [data.x for data in train_data]
    y1 = [data.y1 for data in train_data]
    y2 = [data.y2 for data in train_data]
    y3 = [data.y3 for data in train_data]
    y4 = [data.y4 for data in train_data]

    plt.figure(figsize=(10, 6))
    plt.plot(x, y1, label='y1')
    plt.plot(x, y2, label='y2')
    plt.plot(x, y3, label='y3')
    plt.plot(x, y4, label='y4')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Train Data')
    plt.legend()
    plt.show()

# Define a function to plot data from the Test table
def plot_test_data(session):
    test_data = session.query(Test).all()
    x = [data.x for data in test_data]
    y = [data.y for data in test_data]
    func_num=[data.func_num for data in test_data]
    delta_x=[data.delta_x for data in test_data]
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, label='Test Data', color='r')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Test Data')
    plt.legend()
    plt.show()
    plt.scatter(delta_x, func_num, label='Test Results', color='r')
    plt.xlabel('delta_x')
    plt.ylabel('func_num')
    plt.title('Test Results')
    plt.legend()
    plt.show()



# Create a session to interact with the database
engine = create_engine('sqlite:///assignment_data.db')  # Update with your database URL
Session = sessionmaker(bind=engine)
session = Session()

# Call the functions to create visualizations
plot_train_data(session)
plot_test_data(session)

# %%
import unittest
import pandas as pd
import numpy as np

class TestIdealFunctions(unittest.TestCase):
    def setUp(self):
        # Create simpler sample data for training and ideal functions
        self.train_data = pd.DataFrame({
            'x': np.linspace(-20.0, 19.9, 100),  # Reduced point count for simplicity
            'y1': np.linspace(-10, 10, 100),  # Linear data
            'y2': np.linspace(10, -10, 100),  # Linear data in reverse
            'y3': np.linspace(-5, 5, 100),    # Smaller range linear data
            'y4': np.linspace(5, -5, 100)     # Smaller range linear data in reverse
        })
        self.ideal_functions = pd.DataFrame({
            'x': np.linspace(-20.0, 19.9, 100),  # Matching x range for alignment
            'func1': np.linspace(-10, 10, 100),  # Directly matching y1
            'func2': np.linspace(10, -10, 100),  # Directly matching y2
            'func3': np.linspace(-5, 5, 100),   # Directly matching y3
            'func4': np.linspace(5, -5, 100)    # Directly matching y4
        })

    def test_valid_input(self):
        # Test with valid inputs
        best_funcs = find_best_ideal_functions(self.train_data, self.ideal_functions, 4)
        expected_funcs = {
            'IdealFunc1': 'func1',
            'IdealFunc2': 'func2',
            'IdealFunc3': 'func3',
            'IdealFunc4': 'func4'  # Adjusted to expect a direct match to y4
        }
        self.assertEqual(best_funcs, expected_funcs)

if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.004s
#
# OK

# %%
import unittest

class TestDataMapping(unittest.TestCase):
    # def map_test_data(test_data, ideal_functions, best_funcs):
    #     mapped_data = test_data.copy()
    #     for key, func in best_funcs.items():
    #         mapped_data['func_num'] = func
    #         mapped_data['delta_x'] = np.abs(test_data[key] - ideal_functions[func])
    #     return mapped_data
    def test_map_test_data(self):
        # Sample data setup
        test_data = pd.DataFrame({'x': [1, 2, 3], 'y': [10, 20, 30]})
        ideal_functions = pd.DataFrame({'x': [1, 2, 3], 'func1': [10, 20, 30], 'func2': [9, 19, 29]})
        best_funcs = {'y': 'func1'}
        
        # Function call
        result = map_test_data(test_data, ideal_functions, best_funcs)
        
        # Check if the function returns the expected DataFrame structure and values
        expected_output = pd.DataFrame({
            'x': [1, 2, 3],
            'y': [10, 20, 30],
            'delta_x': [0.0, 0.0, 0.0],
            'func_num': ['func1', 'func1', 'func1']
        })
        pd.testing.assert_frame_equal(result, expected_output)
if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.004s
#
# OK
